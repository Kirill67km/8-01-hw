# %% [markdown]
# ## Домашнее задание «Функции pandas»

# %% [markdown]
# ## Задание 1
#
# Напишите функцию, которая классифицирует фильмы из материалов занятия по правилам:
#
# оценка 2 и ниже — низкий рейтинг;
# оценка 4 и ниже — средний рейтинг;
# оценка 4.5 и 5 — высокий рейтинг
#
# Результат классификации запишите в столбец class.

# %%
import pandas as pd
data = pd.read_csv('/home/galchonkov/netology/pyda_homeworks/ratings.csv')

def class_rating(rating):
    if rating <= 2.0:
        return 'низкий рейтинг'
    elif rating <= 4.0:
        return 'средний рейтинг'
    elif 4.5 <= rating <= 5.0:
        return 'высокий рейтинг'


data['rating_filter'] = data['rating'].apply(class_rating)
data.head()
# Out:
#    userId  movieId  rating   timestamp    rating_filter
# 0       1       31     2.5  1260759144  средний рейтинг
# 1       1     1029     3.0  1260759179  средний рейтинг
# 2       1     1061     3.0  1260759182  средний рейтинг
# 3       1     1129     2.0  1260759185   низкий рейтинг
# 4       1     1172     4.0  1260759205  средний рейтинг

# %% [markdown]
# ## Задание 2
#
# Используйте файл keywords.csv.
#
# Нужно написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определённому региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:

# %%
geo_data = {

1 'Центр': ['москва', 'тула', 'ярославль'],

2 'Северо-Запад': ['петербург', 'псков', 'мурманск'],

3 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
}

# %% [markdown]
# Результат классификации запишите в отдельный столбец region.

# %%
import pandas as pd
data = pd.read_csv('/home/galchonkov/netology/pyda_homeworks/keywords.csv')

def geo_filter(keyword):
    """Гео-фильтрация поисковых запросов"""

    geo_centr = ['москва', 'тула', 'ярославль']
    geo_sz = ['петербург', 'псков', 'мурманск']
    geo_dv = ['владивосток', 'сахалин', 'хабаровск']
    #res = any(ele in keyword for ele in geo_centr)
    if any(ele in keyword for ele in geo_centr) :
        return 'Центр'
    elif any(ele in keyword for ele in geo_sz):
        return 'Северо-Запад'
    elif any(ele in keyword for ele in geo_dv):
        return 'Дальний Восток'
    else:
        return 'undefined'

data['region'] = data['keyword'].apply(geo_filter)
data_2 = data[data.region == 'Северо-Запад']
data_2.head(10)
# Out:
#                                                 keyword   shows        region
# 370                            авито ру санкт петербург  425134  Северо-Запад
# 564                           погода в санкт петербурге  292489  Северо-Запад
# 1236                               банк санкт петербург  174375  Северо-Запад
# 1346                                    санкт петербург  144232  Северо-Запад
# 2121  электронный дневник санкт петербургского образ...   94835  Северо-Запад
# 2153                                        авито псков   98931  Северо-Запад
# 2398                                     авито мурманск   89787  Северо-Запад
# 2550                 банк санкт петербург интернет банк   89123  Северо-Запад
# 2974                            авто ру санкт петербург   74918  Северо-Запад
# 4492                             авито санкт петербурге   53715  Северо-Запад
